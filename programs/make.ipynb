# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tf.app import use

# %%
A = use("Nino-cunei/oldassyrian", hoist=globals())
# A = use("Nino-cunei/oldassyrian:clone", checkout="clone", hoist=globals())
# Out:
# **Locating corpus resources ...**
# The requested app is not available offline
# 	~/text-fabric-data/github/Nino-cunei/oldassyrian/app not found
# Status: latest release online <b>v0.1</b> versus <b>None</b> locally
# downloading app, main data and requested additions ...
# <b title="latest release">app:</b> <span title="unknown release or commit">~/text-fabric-data/github/Nino-cunei/oldassyrian/app</span>
# <b title="local release">data:</b> <span title="rv0.1=#g37d69e8912f331eb5749524e58526d8666c21a99 offline under /Users/me/text-fabric-data/github">~/text-fabric-data/github/Nino-cunei/oldassyrian/tf/0.1</span>
#    |     0.58s T otype                from ~/text-fabric-data/github/Nino-cunei/oldassyrian/tf/0.1
#    |     6.66s T oslots               from ~/text-fabric-data/github/Nino-cunei/oldassyrian/tf/0.1
#    |     0.24s T atfpost              from ~/text-fabric-data/github/Nino-cunei/oldassyrian/tf/0.1
# ...

# %%
A.zipAll()
# Out:
# Data to be zipped:
# 	OK       app                      (v0.1 c21a99)       : ~/github/Nino-cunei/oldassyrian/app
# 	OK       main data                (v0.1 c21a99)       : ~/github/Nino-cunei/oldassyrian/tf/0.1
# Writing zip file ...
# '~/Downloads/github/Nino-cunei/oldassyrian/complete.zip'
